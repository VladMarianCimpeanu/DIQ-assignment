# %% [markdown]
# The targeted class is always the last column, for all the assigned datasets

# %%
import pandas as pd
import code.dirty_completeness as dc

# %%
df_soybean = pd.read_csv('datasets/soybean.csv')

# %%
df_soybean.head()
# Out:
#       date plant-stand   precip  temp hail         crop-hist area-damaged  \
# 0  october      normal  gt-norm  norm  yes       same-lst-yr    low-areas
# 1   august      normal  gt-norm  norm  yes  same-lst-two-yrs    scattered
# 2     july      normal  gt-norm  norm  yes       same-lst-yr    scattered
# 3     july      normal  gt-norm  norm  yes       same-lst-yr    scattered
# 4  october      normal  gt-norm  norm  yes  same-lst-two-yrs    scattered
#
#      severity   seed-tmt germination  ... sclerotia fruit-pods fruit-spots  \
# 0  pot-severe       none      90-100  ...    absent       norm         dna
# 1      severe  fungicide       80-89  ...    absent       norm         dna
# 2      severe  fungicide       lt-80  ...    absent       norm         dna
# 3      severe       none       80-89  ...    absent       norm         dna
# 4  pot-severe       none       lt-80  ...    absent       norm         dna
#
#    seed mold-growth seed-discolor seed-size shriveling roots  \
# 0  norm      absent        absent      norm     absent  norm
# 1  norm      absent        absent      norm     absent  norm
# 2  norm      absent        absent      norm     absent  norm
# 3  norm      absent        absent      norm     absent  norm
# 4  norm      absent        absent      norm     absent  norm
#
#                    class
# 0  diaporthe-stem-canker
# 1  diaporthe-stem-canker
# 2  diaporthe-stem-canker
# 3  diaporthe-stem-canker
# 4  diaporthe-stem-canker
#
# [5 rows x 36 columns]

# %%
# creates 5 df with injections
dc.injection(df_soybean, 1, 'soybean', 'class')
# Out:
# saved soybean-completeness50%
# saved soybean-completeness60%
# saved soybean-completeness70%
# saved soybean-completeness80%
# saved soybean-completeness90%
# [          date plant-stand   precip     temp hail         crop-hist  \
#  0          NaN      normal  gt-norm      NaN  NaN       same-lst-yr
#  1       august         NaN      NaN      NaN  yes               NaN
#  2          NaN      normal      NaN     norm  NaN       same-lst-yr
#  3          NaN         NaN      NaN      NaN  yes               NaN
#  4          NaN      normal      NaN      NaN  NaN               NaN
#  ..         ...         ...      ...      ...  ...               ...
#  244  september         NaN      NaN      NaN  NaN               NaN
#  245  september         NaN  gt-norm     norm  NaN  same-lst-sev-yrs
#  246        NaN      normal      NaN      NaN  NaN               NaN
#  247        NaN      normal     norm  gt-norm  yes               NaN
#  248  september      normal     norm     norm  yes               NaN
#
#      area-damaged    severity   seed-tmt germination  ... sclerotia fruit-pods  \
#  0      low-areas  pot-severe       none         NaN  ...    absent       norm
#  1            NaN      severe  fungicide         NaN  ...       NaN        NaN
#  2      scattered         NaN  fungicide         NaN  ...       NaN        NaN
#  3      scattered      severe        NaN         NaN  ...       NaN        NaN
#  4            NaN  pot-severe        NaN         NaN  ...       NaN        NaN
#  ..           ...         ...        ...         ...  ...       ...        ...
#  244          NaN         NaN  fungicide         NaN  ...    absent   diseased
#  245          NaN         NaN       none         NaN  ...       NaN   diseased
#  246  upper-areas         NaN        NaN         NaN  ...       NaN       norm
#  247          NaN       minor        NaN         NaN  ...       NaN        NaN
#  248  whole-field         NaN      other      90-100  ...    absent   diseased
#
#              fruit-spots    seed mold-growth seed-discolor seed-size  \
#  0                   dna    norm         NaN           NaN      norm
#  1                   NaN    norm         NaN           NaN      norm
#  2                   NaN    norm      absent           NaN       NaN
#  3                   dna     NaN         NaN           NaN      norm
#  4                   NaN    norm         NaN           NaN       NaN
#  ..                  ...     ...         ...           ...       ...
#  244             colored    norm      absent        absent       NaN
#  245             colored     NaN      absent        absent       NaN
#  246              absent     NaN         NaN        absent      norm
#  247  brown-w/blk-specks  abnorm      absent       present   lt-norm
#  248                 NaN    norm      absent           NaN      norm
#
#      shriveling roots                  class
#  0       absent  norm  diaporthe-stem-canker
#  1          NaN   NaN  diaporthe-stem-canker
#  2       absent   NaN  diaporthe-stem-canker
#  3          NaN   NaN  diaporthe-stem-canker
#  4       absent   NaN  diaporthe-stem-canker
#  ..         ...   ...                    ...
#  244     absent   NaN     frog-eye-leaf-spot
#  245        NaN   NaN     frog-eye-leaf-spot
#  246        NaN   NaN     frog-eye-leaf-spot
#  247        NaN  norm     frog-eye-leaf-spot
#  248        NaN  norm     frog-eye-leaf-spot
#
#  [249 rows x 36 columns],
#            date plant-stand   precip     temp hail         crop-hist  \
#  0      october      normal  gt-norm      NaN  NaN               NaN
#  1       august         NaN      NaN      NaN  yes  same-lst-two-yrs
#  2         july      normal      NaN      NaN  yes               NaN
#  3         july      normal      NaN     norm  yes       same-lst-yr
#  4      october      normal  gt-norm     norm  NaN  same-lst-two-yrs
#  ..         ...         ...      ...      ...  ...               ...
#  244        NaN         NaN      NaN      NaN  yes  same-lst-two-yrs
#  245  september      normal      NaN      NaN  yes               NaN
#  246       july         NaN  gt-norm     norm  yes               NaN
#  247        NaN      normal     norm  gt-norm  NaN  same-lst-sev-yrs
#  248        NaN      normal     norm     norm  yes       same-lst-yr
#
#      area-damaged    severity   seed-tmt germination  ... sclerotia fruit-pods  \
#  0            NaN         NaN        NaN      90-100  ...       NaN       norm
#  1      scattered      severe  fungicide       80-89  ...       NaN        NaN
#  2      scattered      severe  fungicide         NaN  ...       NaN       norm
#  3      scattered      severe        NaN         NaN  ...       NaN       norm
#  4      scattered         NaN       none         NaN  ...       NaN       norm
#  ..           ...         ...        ...         ...  ...       ...        ...
#  244    low-areas         NaN  fungicide       80-89  ...    absent        NaN
#  245    scattered  pot-severe        NaN         NaN  ...    absent        NaN
#  246  upper-areas         NaN       none       80-89  ...    absent        NaN
#  247  whole-field         NaN        NaN         NaN  ...    absent        NaN
#  248  whole-field         NaN      other      90-100  ...    absent        NaN
#
#      fruit-spots    seed mold-growth seed-discolor seed-size shriveling roots  \
#  0           dna    norm         NaN        absent      norm     absent  norm
#  1           NaN     NaN         NaN        absent      norm        NaN  norm
#  2           dna    norm      absent        absent      norm     absent   NaN
#  3           dna     NaN         NaN           NaN      norm        NaN   NaN
#  4           dna     NaN         NaN        absent      norm     absent   NaN
#  ..          ...     ...         ...           ...       ...        ...   ...
#  244         NaN    norm      absent           NaN      norm     absent   NaN
#  245     colored    norm      absent        absent      norm        NaN   NaN
#  246      absent    norm      absent        absent      norm     absent  norm
#  247         NaN  abnorm      absent       present       NaN        NaN  norm
#  248     colored     NaN      absent           NaN      norm     absent   NaN
#
#                       class
#  0    diaporthe-stem-canker
#  1    diaporthe-stem-canker
#  2    diaporthe-stem-canker
#  3    diaporthe-stem-canker
#  4    diaporthe-stem-canker
#  ..                     ...
#  244     frog-eye-leaf-spot
#  245     frog-eye-leaf-spot
#  246     frog-eye-leaf-spot
#  247     frog-eye-leaf-spot
#  248     frog-eye-leaf-spot
#
#  [249 rows x 36 columns],
#            date plant-stand   precip  temp hail         crop-hist area-damaged  \
#  0      october      normal  gt-norm   NaN  NaN       same-lst-yr    low-areas
#  1       august      normal  gt-norm  norm  yes  same-lst-two-yrs    scattered
#  2          NaN      normal  gt-norm   NaN  NaN       same-lst-yr    scattered
#  3         july         NaN  gt-norm  norm  NaN       same-lst-yr          NaN
#  4      october      normal  gt-norm  norm  yes  same-lst-two-yrs    scattered
#  ..         ...         ...      ...   ...  ...               ...          ...
#  244  september         NaN  gt-norm   NaN  NaN  same-lst-two-yrs    low-areas
#  245  september      normal      NaN  norm  yes  same-lst-sev-yrs    scattered
#  246       july      normal      NaN  norm  yes               NaN          NaN
#  247        NaN         NaN     norm   NaN  yes  same-lst-sev-yrs          NaN
#  248  september      normal     norm  norm  yes       same-lst-yr  whole-field
#
#         severity   seed-tmt germination  ... sclerotia fruit-pods fruit-spots  \
#  0    pot-severe       none      90-100  ...    absent       norm         dna
#  1           NaN  fungicide         NaN  ...       NaN       norm         dna
#  2        severe  fungicide       lt-80  ...    absent       norm         dna
#  3           NaN       none       80-89  ...    absent       norm         NaN
#  4           NaN        NaN         NaN  ...    absent       norm         NaN
#  ..          ...        ...         ...  ...       ...        ...         ...
#  244       minor  fungicide       80-89  ...       NaN   diseased         NaN
#  245  pot-severe        NaN      90-100  ...       NaN   diseased     colored
#  246  pot-severe       none         NaN  ...    absent       norm         NaN
#  247       minor  fungicide         NaN  ...       NaN        NaN         NaN
#  248  pot-severe        NaN         NaN  ...    absent   diseased     colored
#
#         seed mold-growth seed-discolor seed-size shriveling roots  \
#  0      norm      absent        absent      norm     absent   NaN
#  1      norm      absent        absent       NaN     absent  norm
#  2      norm      absent           NaN       NaN        NaN  norm
#  3      norm      absent        absent      norm        NaN  norm
#  4      norm      absent        absent       NaN        NaN  norm
#  ..      ...         ...           ...       ...        ...   ...
#  244     NaN         NaN           NaN      norm     absent  norm
#  245    norm      absent           NaN       NaN        NaN   NaN
#  246     NaN      absent           NaN      norm     absent  norm
#  247  abnorm      absent       present   lt-norm    present  norm
#  248     NaN      absent        absent      norm     absent  norm
#
#                       class
#  0    diaporthe-stem-canker
#  1    diaporthe-stem-canker
#  2    diaporthe-stem-canker
#  3    diaporthe-stem-canker
#  4    diaporthe-stem-canker
#  ..                     ...
#  244     frog-eye-leaf-spot
#  245     frog-eye-leaf-spot
#  246     frog-eye-leaf-spot
#  247     frog-eye-leaf-spot
#  248     frog-eye-leaf-spot
#
#  [249 rows x 36 columns],
#            date plant-stand   precip     temp hail         crop-hist  \
#  0          NaN      normal  gt-norm     norm  yes       same-lst-yr
#  1       august      normal      NaN      NaN  yes  same-lst-two-yrs
#  2         july      normal  gt-norm     norm  NaN       same-lst-yr
#  3          NaN         NaN  gt-norm     norm  yes               NaN
#  4      october      normal  gt-norm     norm  yes  same-lst-two-yrs
#  ..         ...         ...      ...      ...  ...               ...
#  244  september         NaN      NaN  gt-norm  yes  same-lst-two-yrs
#  245  september      normal  gt-norm      NaN  yes               NaN
#  246       july      normal  gt-norm      NaN  yes       same-lst-yr
#  247    october      normal      NaN  gt-norm  yes  same-lst-sev-yrs
#  248  september         NaN      NaN     norm  yes               NaN
#
#      area-damaged    severity   seed-tmt germination  ... sclerotia fruit-pods  \
#  0            NaN  pot-severe       none      90-100  ...    absent       norm
#  1      scattered      severe        NaN       80-89  ...    absent       norm
#  2      scattered      severe  fungicide       lt-80  ...       NaN       norm
#  3      scattered      severe        NaN       80-89  ...    absent        NaN
#  4      scattered  pot-severe        NaN         NaN  ...    absent       norm
#  ..           ...         ...        ...         ...  ...       ...        ...
#  244    low-areas         NaN        NaN       80-89  ...       NaN   diseased
#  245          NaN         NaN        NaN      90-100  ...    absent   diseased
#  246          NaN         NaN        NaN         NaN  ...    absent       norm
#  247  whole-field       minor  fungicide      90-100  ...    absent   diseased
#  248  whole-field  pot-severe      other      90-100  ...    absent   diseased
#
#              fruit-spots    seed mold-growth seed-discolor seed-size  \
#  0                   dna     NaN      absent           NaN      norm
#  1                   NaN    norm      absent        absent      norm
#  2                   dna     NaN         NaN        absent       NaN
#  3                   NaN    norm      absent        absent      norm
#  4                   dna    norm      absent        absent      norm
#  ..                  ...     ...         ...           ...       ...
#  244             colored    norm      absent        absent      norm
#  245                 NaN    norm      absent        absent       NaN
#  246              absent    norm      absent        absent      norm
#  247  brown-w/blk-specks  abnorm      absent           NaN   lt-norm
#  248             colored     NaN         NaN        absent       NaN
#
#      shriveling roots                  class
#  0       absent   NaN  diaporthe-stem-canker
#  1       absent  norm  diaporthe-stem-canker
#  2       absent  norm  diaporthe-stem-canker
#  3       absent   NaN  diaporthe-stem-canker
#  4       absent  norm  diaporthe-stem-canker
#  ..         ...   ...                    ...
#  244     absent  norm     frog-eye-leaf-spot
#  245     absent  norm     frog-eye-leaf-spot
#  246     absent  norm     frog-eye-leaf-spot
#  247    present  norm     frog-eye-leaf-spot
#  248     absent  norm     frog-eye-leaf-spot
#
#  [249 rows x 36 columns],
#            date plant-stand   precip     temp hail         crop-hist  \
#  0      october      normal  gt-norm     norm  NaN       same-lst-yr
#  1       august      normal  gt-norm     norm  yes  same-lst-two-yrs
#  2         july      normal      NaN     norm  yes       same-lst-yr
#  3         july      normal  gt-norm     norm  yes       same-lst-yr
#  4      october         NaN  gt-norm     norm  yes  same-lst-two-yrs
#  ..         ...         ...      ...      ...  ...               ...
#  244  september         NaN  gt-norm  gt-norm  yes  same-lst-two-yrs
#  245  september      normal  gt-norm     norm  yes  same-lst-sev-yrs
#  246       july      normal  gt-norm     norm  yes               NaN
#  247    october         NaN     norm      NaN  yes  same-lst-sev-yrs
#  248  september      normal      NaN     norm  yes       same-lst-yr
#
#      area-damaged    severity   seed-tmt germination  ... sclerotia fruit-pods  \
#  0      low-areas  pot-severe       none      90-100  ...    absent       norm
#  1      scattered      severe        NaN       80-89  ...       NaN       norm
#  2      scattered      severe  fungicide       lt-80  ...    absent       norm
#  3      scattered      severe        NaN       80-89  ...    absent       norm
#  4      scattered  pot-severe        NaN       lt-80  ...    absent       norm
#  ..           ...         ...        ...         ...  ...       ...        ...
#  244    low-areas       minor  fungicide       80-89  ...    absent   diseased
#  245    scattered  pot-severe       none      90-100  ...    absent   diseased
#  246  upper-areas  pot-severe       none       80-89  ...       NaN       norm
#  247  whole-field       minor  fungicide      90-100  ...       NaN   diseased
#  248  whole-field  pot-severe      other      90-100  ...       NaN   diseased
#
#              fruit-spots    seed mold-growth seed-discolor seed-size  \
#  0                   dna    norm      absent        absent      norm
#  1                   dna     NaN      absent        absent      norm
#  2                   dna    norm      absent        absent      norm
#  3                   dna    norm      absent           NaN      norm
#  4                   dna    norm      absent        absent      norm
#  ..                  ...     ...         ...           ...       ...
#  244             colored    norm      absent        absent      norm
#  245             colored    norm      absent           NaN      norm
#  246              absent    norm      absent        absent      norm
#  247  brown-w/blk-specks  abnorm         NaN       present   lt-norm
#  248                 NaN    norm      absent        absent       NaN
#
#      shriveling roots                  class
#  0       absent  norm  diaporthe-stem-canker
#  1       absent  norm  diaporthe-stem-canker
#  2       absent   NaN  diaporthe-stem-canker
#  3       absent  norm  diaporthe-stem-canker
#  4          NaN  norm  diaporthe-stem-canker
#  ..         ...   ...                    ...
#  244     absent   NaN     frog-eye-leaf-spot
#  245     absent  norm     frog-eye-leaf-spot
#  246     absent  norm     frog-eye-leaf-spot
#  247        NaN  norm     frog-eye-leaf-spot
#  248     absent  norm     frog-eye-leaf-spot
#
#  [249 rows x 36 columns]]
