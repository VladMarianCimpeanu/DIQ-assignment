# %% [markdown]
# The targeted class is always the last column, for all the assigned datasets

# %%
import pandas as pd
import utility.dirty_completeness as dc

# %%
df_adult = pd.read_csv('datasets/adult.csv')

# %%
df_adult.head()
# Out:
#    age         workclass  fnlwgt     education  education-num  \
# 0   42  Self-emp-not-inc   99185  Some-college             10
# 1   55           Private  163083       Masters             14
# 2   49           Private  340755       Masters             14
# 3   31           Private  208881  Some-college             10
# 4   19           Private  271446  Some-college             10
#
#       maritial-status       occupation relationship   race     sex  \
# 0  Married-civ-spouse  Exec-managerial      Husband  White    Male
# 1  Married-civ-spouse   Prof-specialty      Husband  White    Male
# 2  Married-civ-spouse            Sales      Husband  White    Male
# 3  Married-civ-spouse     Craft-repair      Husband  White    Male
# 4       Never-married    Other-service    Own-child  White  Female
#
#    capital-gain  capital-loss  hours-per-week native-country income
# 0             0             0              40  United-States   >50K
# ...

# %%
df_adult.nunique()
# Out:
# age                  68
# workclass             7
# fnlwgt             2862
# education            16
# education-num        16
# maritial-status       7
# occupation           13
# relationship          6
# race                  5
# sex                   2
# capital-gain         59
# capital-loss         40
# hours-per-week       75
# native-country       39
# income                2
# dtype: int64

# %%
# creates 5 df with injections
df_list_adult = dc.injection(df_adult, 1, 'soybean', 'class')
# Out:
# saved soybean-completeness50%
# saved soybean-completeness60%
# saved soybean-completeness70%
# saved soybean-completeness80%
# saved soybean-completeness90%

# %%
df_list_adult[0].head()
# Out:
#     age         workclass    fnlwgt     education  education-num  \
# 0   NaN  Self-emp-not-inc   99185.0           NaN           10.0
# 1  55.0               NaN  163083.0           NaN           14.0
# 2   NaN           Private       NaN           NaN           14.0
# 3   NaN               NaN  208881.0           NaN            NaN
# 4   NaN           Private  271446.0  Some-college           10.0
#
#       maritial-status    occupation relationship   race     sex  capital-gain  \
# 0  Married-civ-spouse           NaN      Husband    NaN    Male           NaN
# 1  Married-civ-spouse           NaN          NaN    NaN     NaN           0.0
# 2  Married-civ-spouse           NaN      Husband  White     NaN           NaN
# 3                 NaN  Craft-repair      Husband    NaN    Male           0.0
# 4                 NaN           NaN          NaN  White  Female           0.0
#
#    capital-loss  hours-per-week native-country income
# ...

# %%
df_list_adult[0].isnull().sum()
# Out:
# age                1493
# workclass          1468
# fnlwgt             1561
# education          1472
# education-num      1489
# maritial-status    1486
# occupation         1482
# relationship       1510
# race               1567
# sex                1514
# capital-gain       1497
# capital-loss       1529
# hours-per-week     1564
# native-country     1485
# income             1460
# dtype: int64

# %%
import missingno as mno
mno.matrix(df_list_adult[0])
# Out:
# <AxesSubplot:>
